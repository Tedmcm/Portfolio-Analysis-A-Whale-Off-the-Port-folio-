# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csv_path = Path('resources/whale_returns.csv')
whale_data = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
whale_data.sort_index(inplace=True)
whale_data.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
# 2015-03-11                   0.004012            0.005163
# 2015-03-12                   0.008265            0.010272
# 2015-03-13                  -0.002497           -0.001428
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
# Count nulls
whale_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_data.dropna(inplace=True)
whale_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
#Count Nulls
whale_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
csv_path = Path("Resources/algo_returns.csv")
algo_data = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
algo_data.sort_index(inplace=True)
algo_data.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# 2014-06-04 -0.001838       NaN
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735

# %%
# Count nulls
algo_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop null
algo_data.dropna(inplace=True)
algo_data.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# 2014-06-12 -0.000028 -0.003841
# 2014-06-13  0.001917 -0.000814
# 2014-06-16  0.001084  0.001831
# 2014-06-17  0.000922  0.006870
# 2014-06-18 -0.006303  0.007228

# %%
#Count Nulls
algo_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csv_path = Path("Resources/sp500_history.csv")
sp_data = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
sp_data.sort_index(inplace=True)
sp_data.head(10)
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93
# 2012-10-08  $1455.88
# 2012-10-09  $1441.48
# 2012-10-10  $1432.56
# 2012-10-11  $1432.84
# 2012-10-12  $1428.59

# %%
# Check Data Types
sp_data.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_data['Close'] = sp_data['Close'].str.replace("$", "")
sp_data['Close'] = sp_data['Close'].astype(float)

# %%
#Check Dtypes to verify Change
sp_data.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
daily_returns = sp_data.pct_change()
daily_returns
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1649 rows x 1 columns]

# %%
# Drop Nulls
daily_returns.dropna(inplace=True)
daily_returns
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
# Rename Column name
daily_returns = daily_returns.rename(columns={'Close':'sp_500'})

# %%
#Reassignment 
sp_data = daily_returns
daily_returns.head()
# Out:
#               sp_500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
combined_data = pd.concat([whale_data, algo_data, sp_data],axis="columns", join="inner")
combined_data.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
# 2015-03-11                   0.004012            0.005163
# 2015-03-12                   0.008265            0.010272
# 2015-03-13                  -0.002497           -0.001428
# 2015-03-16                   0.007901            0.003583
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# ...

# %% [markdown]
# ---

# %% [markdown]
# Performance:
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %% [markdown]
# I did each Portfolio/CSV file(whale, algo, S&P) seperately and then the combined portfolio's

# %%
# Plot whale daily returns
whale_data.plot(figsize=(20,10))

# %%
#Calculate Cumulative Returns Whale port
whale_cumulative = (1 + whale_data).cumprod()
whale_cumulative.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
# 2015-03-10                   0.987379            0.997595
# 2015-03-11                   0.991340            1.002746
# 2015-03-12                   0.999533            1.013045
# 2015-03-13                   0.997037            1.011598
# 2015-03-16                   1.004914            1.015222
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                     0.999504                0.993431
# 2015-03-04                     0.996972                0.997617
# 2015-03-05                     0.999319                1.004327
# ...

# %%
#Plot Cumulative Returns Whale
whale_cumulative.plot(figsize=(20,10))

# %%
#Plot SP Daily Returns
sp_data.plot(figsize=(20,10))

# %%
# Calculate SP cumulative returns
sp_cumulative = (1 + sp_data).cumprod()
sp_cumulative.head(10)
# Out:
#               sp_500
# Date
# 2012-10-02  1.000872
# 2012-10-03  1.004500
# 2012-10-04  1.011707
# 2012-10-05  1.011381
# 2012-10-08  1.007885
# 2012-10-09  0.997916
# 2012-10-10  0.991741
# 2012-10-11  0.991935
# 2012-10-12  0.988993
# 2012-10-15  0.996982

# %%
# Plot SP cumulative returns
sp_cumulative.plot(figsize=(20,10))

# %%
#Plot Daily Returnds ALGO
algo_data.plot(figsize=(20,10))

# %%
#Calculate Cumulative ALGO
algo_cumulative = (1 + algo_data).cumprod()    
algo_cumulative.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  1.004062  1.013285
# 2014-06-06  1.005927  1.021679
# 2014-06-09  1.000885  1.027470
# 2014-06-10  1.005295  1.026714
# 2014-06-11  1.010081  1.022852
# 2014-06-12  1.010052  1.018923
# 2014-06-13  1.011989  1.018094
# 2014-06-16  1.013086  1.019958
# 2014-06-17  1.014020  1.026964
# 2014-06-18  1.007628  1.034387

# %%
#Plot Cumulative ALGO
algo_cumulative.plot(figsize=(20,10))

# %%
#Plot Combined PORT Returns
combined_data.plot(figsize=(20,10))

# %%
#Calculate Cumulative Combined Port
combined_cum_data = (1 + combined_data).cumprod()    
combined_cum_data.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
# 2015-03-10                   0.987379            0.997595
# 2015-03-11                   0.991340            1.002746
# 2015-03-12                   0.999533            1.013045
# 2015-03-13                   0.997037            1.011598
# 2015-03-16                   1.004914            1.015222
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# ...

# %%
#Plot Cumuluative Combined Port
combined_cum_data.plot(figsize=(20,10))

# %% [markdown]
# The ALGO 1 & BERKSHIRE Portfolios outperform the S&P

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# I did it individually and with the combined portfolios

# %%
#Whale Port Boxplot
whale_data.boxplot(figsize=(20,10))

# %%
#SP Boxplot
sp_data.boxplot(figsize=(20,10))

# %%
#ALGO Boxplot
algo_data.boxplot(figsize=(20,10))

# %%
#Combined Portfolio's Boxplot
combined_data.boxplot(figsize=(20,10))

# %%
#Whale Port Stand Dev
whale_stan = whale_data.std()
whale_stan.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %%
#SP Port Standard Dev
sp_stan = sp_data.std()
sp_stan.head()
# Out:
# sp_500    0.008111
# dtype: float64

# %%
#ALGO Port Standard Dev
algo_stan = algo_data.std()
algo_stan.head()
# Out:
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64

# %%
#Combined Port stan Dev
combined_data_stan = combined_data.std()
combined_data_stan.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# sp_500                         0.008554
# dtype: float64

# %%
#Annualized Std for WHALE (Whale-252)
whale_annual_std = whale_stan * np.sqrt(252)
whale_annual_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.124487
# PAULSON & CO.INC.              0.110754
# TIGER GLOBAL MANAGEMENT LLC    0.171830
# BERKSHIRE HATHAWAY INC         0.203682
# dtype: float64

# %%
#Annualized Std for SP (SP-252)
sp_annual_std = sp_stan * np.sqrt(252)
sp_annual_std.head()
# Out:
# sp_500    0.128762
# dtype: float64

# %%
#Annualized Std for ALGO (ALGO-252)
algo_annual_std = algo_stan * np.sqrt(252)
algo_annual_std.head()
# Out:
# Algo 1    0.126801
# Algo 2    0.134401
# dtype: float64

# %%
#Combined Port Annual Stan Dev
combined_annual_data_stan = combined_data_stan * np.sqrt(252)
combined_annual_data_stan.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# sp_500                         0.135786
# dtype: float64

# %%
# Which portfolios are riskier than the S&P 500?
whale_annual_std = np.random.normal(scale=whale_annual_std.mean(), size=10000)
sp_annual_std = np.random.normal(scale=sp_annual_std, size=10000)
algo_annual_std = np.random.normal(scale=algo_annual_std.mean(), size=10000)

portfolio_std = pd.DataFrame({
    "whale": whale_annual_std,
    "sp": sp_annual_std,
    "algo": algo_annual_std
})

portfolio_std.plot.hist(stacked=True, bins=100)

# %% [markdown]
# According to the risk analysis the algo porfolio's are riskier than the S&P and the Whale portfolio's are not.

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %% [markdown]
# I did them individually and combined.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window

#Rolling 21-Day-STD for S&P Port
sp_roll_std = sp_data.rolling(window=21).std()
sp_roll_std.plot(figsize=(20,10))

# %%
#Rolling 21-Day-STD for Whale Port
whale_roll_std = whale_data.rolling(window=21).std()
whale_roll_std.plot(figsize=(20,10))

# %%
#Rolling 21-Day-STD for ALGO
algo_roll_std = algo_data.rolling(window=21).std()
algo_roll_std.plot(figsize=(20,10))

# %%
#Combined Portfolio's rolling Std Chart
combined_roll_std = combined_data.rolling(window=21).std()
combined_roll_std.plot(figsize=(20,10))

# %% [markdown]
# From this analysis it does appear that risk rises at roughly the same time for each of the portfolio's

# %%
# Construct a correlation table
port_correlation = pd.concat([sp_roll_std, whale_roll_std, algo_roll_std], axis='columns', join='inner').corr()
print(port_correlation)
# Out:
#                                sp_500  SOROS FUND MANAGEMENT LLC  \
# sp_500                       1.000000                   0.908859
# SOROS FUND MANAGEMENT LLC    0.908859                   1.000000
# PAULSON & CO.INC.            0.594410                   0.663975
# TIGER GLOBAL MANAGEMENT LLC  0.410637                   0.449124
# BERKSHIRE HATHAWAY INC       0.811634                   0.856207
# Algo 1                       0.699807                   0.715645
# Algo 2                       0.898086                   0.866933
#
#                              PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# sp_500                                 0.594410                     0.410637
# SOROS FUND MANAGEMENT LLC              0.663975                     0.449124
# PAULSON & CO.INC.                      1.000000                     0.405818
# TIGER GLOBAL MANAGEMENT LLC            0.405818                     1.000000
# ...

# %%
# Construct a correlation table Heatmap
ax=sns.heatmap(port_correlation, vmin=-1, vmax=1, center=0, square=True)

# %% [markdown]
# Which returns most closely mimic the S&P? According to the above pivot table Berkshire Hathaway's portfolios most closely mimic the S&P.

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# Calculate covariance of daily returns of Soros Fund MAN vs. S&P 500
covariance = whale_data['SOROS FUND MANAGEMENT LLC'].cov(sp_data['sp_500'])
covariance
# Out:
# 5.658503197203636e-05

# %%
#Calculate Variance for SP
variance = sp_data['sp_500'].var()
variance
# Out:
# 6.579270583158746e-05

# %%
#Calculate BETA
SOROS_beta = covariance / variance
SOROS_beta
# Out:
# 0.8600502328765686

# %%
#Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
SOROS_ROLL = whale_data['SOROS FUND MANAGEMENT LLC'].rolling(window=21).cov(sp_data['sp_500']) / sp_data['sp_500'].rolling(window=21).var()
SOROS_ROLL.dropna(inplace=True)
SOROS_ROLL.plot(figsize=(20,10))

# %% [markdown]
# I would conclude that the Soros portfolio has almost no corrolation/beta with/to the S&P/Market W/ A (Beta of .0.0005878170301682635).
# The Pearson Correlation (which is R, not R-squared) is an indication of the extent of the linear relationship between SOROS and the S&P500.

# %% [markdown]
# ---

# %%
# Calculate a rolling window using the exponentially weighted moving average.  
combined_data_ewm = combined_data.ewm(span=20,adjust=False).std()
combined_data_ewm.plot(figsize=(20,10))

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios 
combined_data_sharpe = (combined_data.mean() * 252) / (combined_data.std() * np.sqrt(252))
combined_data_sharpe
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# sp_500                         0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot 
combined_data_sharpe.plot(kind='bar', title='Sharpe Ratios')

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? My Answer: YES!

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock of My Port
csv_path = Path('resources/tsla.csv')
tsla_data = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
tsla_data.head(10)
# Out:
#               TSLA
# Date
# 2018-11-13  338.73
# 2018-11-14  344.00
# 2018-11-15  348.44
# 2018-11-16  354.31
# 2018-11-19  353.47
# 2018-11-20  347.49
# 2018-11-21  338.19
# 2018-11-23  325.83
# 2018-11-26  346.00
# 2018-11-27  343.92

# %%
# Read the second stock of My Port
csv_path = Path('resources/msft.csv')
msft_data = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
msft_data.head(10)
# Out:
#              MSFT
# Date
# 2017-01-03  62.58
# 2017-01-04  62.30
# 2017-01-05  62.30
# 2017-01-06  62.84
# 2017-01-09  62.64
# 2017-01-10  62.62
# 2017-01-11  63.19
# 2017-01-12  62.61
# 2017-01-13  62.70
# 2017-01-17  62.53

# %%
# Read the third stock of My Port
csv_path = Path('resources/aapl.csv')
aapl_data = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
aapl_data.head(10)
# Out:
#               AAPL
# Date
# 2017-01-03  116.15
# 2017-01-04  116.02
# 2017-01-05  116.61
# 2017-01-06  117.91
# 2017-01-09  118.99
# 2017-01-10  119.11
# 2017-01-11  119.75
# 2017-01-12  119.25
# 2017-01-13  119.04
# 2017-01-17  120.00

# %%
# Concatenate all stocks into a single Port..My Port
my_port = pd.concat([tsla_data, msft_data, aapl_data],axis="columns", join="inner")
my_port.head(10)
# Out:
#               TSLA    MSFT    AAPL
# Date
# 2018-11-13  338.73  106.94  192.23
# 2018-11-14  344.00  104.97  186.80
# 2018-11-15  348.44  107.28  191.41
# 2018-11-16  354.31  108.29  193.53
# 2018-11-19  353.47  104.62  185.86
# 2018-11-20  347.49  101.71  176.98
# 2018-11-21  338.19  103.11  176.78
# 2018-11-23  325.83  103.07  172.29
# 2018-11-26  346.00  106.47  174.62
# 2018-11-27  343.92  107.14  174.24

# %%
# Reset the index
my_port.sort_index(inplace=True)
my_port.head(10)
# Out:
#               TSLA    MSFT    AAPL
# Date
# 2018-11-13  338.73  106.94  192.23
# 2018-11-14  344.00  104.97  186.80
# 2018-11-15  348.44  107.28  191.41
# 2018-11-16  354.31  108.29  193.53
# 2018-11-19  353.47  104.62  185.86
# 2018-11-20  347.49  101.71  176.98
# 2018-11-21  338.19  103.11  176.78
# 2018-11-23  325.83  103.07  172.29
# 2018-11-26  346.00  106.47  174.62
# 2018-11-27  343.92  107.14  174.24

# %%
# Pivot so that each column of prices represents a unique symbol 
all_prices = pd.concat([aapl_data, msft_data, tsla_data], axis="columns", join="inner")
all_prices = all_prices.reset_index()
all_prices = all_prices.pivot_table(values=['TSLA', 'MSFT', 'AAPL'], index=["Date"])
all_prices.head()
# Out:
#               AAPL    MSFT    TSLA
# Date
# 2018-11-13  192.23  106.94  338.73
# 2018-11-14  186.80  104.97  344.00
# 2018-11-15  191.41  107.28  348.44
# 2018-11-16  193.53  108.29  354.31
# 2018-11-19  185.86  104.62  353.47

# %%
# Drop Nulls
my_port.dropna(inplace=True)
my_port.head(10)
# Out:
#               TSLA    MSFT    AAPL
# Date
# 2018-11-13  338.73  106.94  192.23
# 2018-11-14  344.00  104.97  186.80
# 2018-11-15  348.44  107.28  191.41
# 2018-11-16  354.31  108.29  193.53
# 2018-11-19  353.47  104.62  185.86
# 2018-11-20  347.49  101.71  176.98
# 2018-11-21  338.19  103.11  176.78
# 2018-11-23  325.83  103.07  172.29
# 2018-11-26  346.00  106.47  174.62
# 2018-11-27  343.92  107.14  174.24

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
my_port = my_port.pct_change()
my_port.dropna(inplace=True)
my_port_returns = my_port.dot(weights)
my_port_returns.dropna(inplace=True)
my_port_returns = my_port_returns.to_frame()
my_port_returns.head(10)
# Out:
#                    0
# Date
# 2018-11-14 -0.010370
# 2018-11-15  0.019864
# 2018-11-16  0.012446
# 2018-11-19 -0.025298
# 2018-11-20 -0.030837
# 2018-11-21 -0.004710
# 2018-11-23 -0.020778
# 2018-11-26  0.036138
# 2018-11-27 -0.000632
# 2018-11-28  0.029029

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Added portfolio to the larger dataframe of fund returns, (Rename port = my port)
all_port= pd.concat([my_port_returns, combined_data], axis="columns", join="inner")
all_port = all_port.rename(columns={0:'My Port'})
all_port.head(10)
# Out:
#              My Port  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-11-14 -0.010370                  -0.001917           -0.008304
# 2018-11-15  0.019864                   0.006886            0.006806
# 2018-11-16  0.012446                   0.005377           -0.000211
# 2018-11-19 -0.025298                  -0.017277           -0.012187
# 2018-11-20 -0.030837                  -0.022215           -0.016306
# 2018-11-21 -0.004710                   0.012991            0.009498
# 2018-11-23 -0.020778                   0.001720           -0.000739
# 2018-11-26  0.036138                   0.017137           -0.002214
# 2018-11-27 -0.000632                   0.005143           -0.000801
# 2018-11-28  0.029029                   0.014748            0.013723
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-11-14                    -0.010577                0.006289  0.003043
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_port.dropna(inplace=True)
all_port.head(10)
# Out:
#              My Port  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-11-14 -0.010370                  -0.001917           -0.008304
# 2018-11-15  0.019864                   0.006886            0.006806
# 2018-11-16  0.012446                   0.005377           -0.000211
# 2018-11-19 -0.025298                  -0.017277           -0.012187
# 2018-11-20 -0.030837                  -0.022215           -0.016306
# 2018-11-21 -0.004710                   0.012991            0.009498
# 2018-11-23 -0.020778                   0.001720           -0.000739
# 2018-11-26  0.036138                   0.017137           -0.002214
# 2018-11-27 -0.000632                   0.005143           -0.000801
# 2018-11-28  0.029029                   0.014748            0.013723
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-11-14                    -0.010577                0.006289  0.003043
# ...

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk                   
# All Port Box Plot
all_port.boxplot(figsize=(20,10))

# %%
#All Portfolio's Stan Dev
all_port_stan = all_port.std()  
all_port_stan.head(10)
# Out:
# My Port                        0.019359
# SOROS FUND MANAGEMENT LLC      0.010254
# PAULSON & CO.INC.              0.008444
# TIGER GLOBAL MANAGEMENT LLC    0.016977
# BERKSHIRE HATHAWAY INC         0.016416
# Algo 1                         0.010154
# Algo 2                         0.010319
# sp_500                         0.011196
# dtype: float64

# %%
#All Portfolio's Annual Stan Dev
all_port_annual_std = all_port_stan * np.sqrt(252)
all_port_annual_std.head(10)
# Out:
# My Port                        0.307314
# SOROS FUND MANAGEMENT LLC      0.162774
# PAULSON & CO.INC.              0.134050
# TIGER GLOBAL MANAGEMENT LLC    0.269506
# BERKSHIRE HATHAWAY INC         0.260593
# Algo 1                         0.161195
# Algo 2                         0.163811
# sp_500                         0.177732
# dtype: float64

# %%
#Chart All Port Stan Dev vs SP
all_port_annual_std = np.random.normal(scale=all_port_stan.mean(), size=10000)  
sp_annual_std = np.random.normal(scale=sp_data.std(), size=10000)

all_port_std = pd.DataFrame({
    
    'all_port': all_port_annual_std,
    'sp': sp_annual_std
})

all_port_std.plot.hist(stacked=True, bins=100)

# %%
#My Port Stan Dev
my_port_stan = my_port_returns.std()  
my_port_stan.head()
# Out:
# 0    0.019138
# dtype: float64

# %%
#My Port Annual Stan Dev
my_port_annual_std = my_port_stan * np.sqrt(252)
my_port_annual_std.head()
# Out:
# 0    0.303801
# dtype: float64

# %%
#My Port Annual Stan Dev vs SP Chart
my_port_annual_std = np.random.normal(scale=all_port_stan.mean(), size=10000)  
sp_annual_std = np.random.normal(scale=sp_data.std(), size=10000)

my_port_std = pd.DataFrame({
    
    'My_Port': my_port_annual_std,
    'sp': sp_annual_std
})

my_port_std.plot.hist(stacked=True, bins=100)

# %%
# Rolling
#The plotted rolling standard deviation using a 21 trading day window for all portfolios.
all_port_std = all_port.rolling(window=21).std()
all_port_std.plot(figsize=(20,10))

# %%
# Annualized Sharpe Ratios.. (Comparing mine at this point in the exercise it diverged from the starter code and I could not figure out why? It must be how I used/concated the
#combined data variable, I went back and checked it but cant figure out why my ratios below were so much higher than the starter code?) 
all_sharpe_ratios = (all_port.mean() * 252) / (all_port.std() * np.sqrt(252))
all_sharpe_ratios
# Out:
# My Port                        0.215043
# SOROS FUND MANAGEMENT LLC      1.527228
# PAULSON & CO.INC.             -0.252493
# TIGER GLOBAL MANAGEMENT LLC   -1.640663
# BERKSHIRE HATHAWAY INC         1.908924
# Algo 1                         2.237573
# Algo 2                         1.147206
# sp_500                         1.070512
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
all_sharpe_ratios.plot(kind='bar', title='Sharpe Ratios')

# %%
#Correlation Table         
all_port_correlation = all_port.corr()
print(all_port_correlation)
# Out:
#                               My Port  SOROS FUND MANAGEMENT LLC  \
# My Port                      1.000000                   0.686387
# SOROS FUND MANAGEMENT LLC    0.686387                   1.000000
# PAULSON & CO.INC.            0.578328                   0.832952
# TIGER GLOBAL MANAGEMENT LLC  0.310981                   0.509622
# BERKSHIRE HATHAWAY INC       0.781658                   0.844522
# Algo 1                       0.194339                   0.320904
# Algo 2                       0.672678                   0.870440
# sp_500                       0.808790                   0.883202
#
#                              PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# My Port                                0.578328                     0.310981
# SOROS FUND MANAGEMENT LLC              0.832952                     0.509622
# PAULSON & CO.INC.                      1.000000                     0.434606
# ...

# %%
#Correlation Heat Map all Portfolio
ax=sns.heatmap(all_port_correlation, vmin=-1, vmax=1, center=0, square=True)

# %%
#Using your custom portfolio and one other of your choosing:
#My Port beta vs SP
#Calculate Covariance
covariance = all_port['My Port'].cov(sp_data['sp_500'])
covariance
# Out:
# 0.00017530040619114092

# %%
#Calculate Variance for SP
variance = sp_data['sp_500'].var()
variance
# Out:
# 6.579270583158746e-05

# %%
#Calculate BETA
my_port_beta = covariance / variance
my_port_beta
# Out:
# 2.664435274023617

# %%
# Calculate/Chart the My Port Beta vs the S&P with rolling window using 21 Day. 
my_port_roll = all_port['My Port'].rolling(window=21).cov(sp_data['sp_500']) / sp_data['sp_500'].rolling(window=21).var()
my_port_roll.dropna(inplace=True)
my_port_roll.plot(figsize=(20,10))

# %% [markdown]
# My portfolio...what can I say.. I love Beta... 2.6! Its about what I would expect w/TSLA, APPL and MSFT.. W/Out TSLA I would suspect it would drop dramatically.

# %%
#The Following are all Extra Charts
# My Port exponentially weighted moving average.  
my_port_ewm = my_port_returns.ewm(span=20,adjust=False).std()
my_port_ewm.plot(figsize=(20,10))

# %%
# My Port exponentially weighted moving average. (Individual Stocks in My Port) 
my_port_ewm = my_port.ewm(span=20,adjust=False).std()
my_port_ewm.plot(figsize=(20,10))

# %%
# All Port exponentially weighted moving average.  
all_port_ewm = all_port.ewm(span=20,adjust=False).std()
all_port_ewm.plot(figsize=(20,10))
